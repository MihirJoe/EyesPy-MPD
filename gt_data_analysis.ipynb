# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('ground_truth_measurements.xlsx')

# %%
df.describe()
# Out:
#        vpf_expected  mrd1_expected  vpf  mrd1
# count    178.000000     178.000000  0.0   0.0
# mean       7.013933       2.416348  NaN   NaN
# std        3.302907       1.566719  NaN   NaN
# min        0.000000       0.000000  NaN   NaN
# 25%        5.777500       0.822500  NaN   NaN
# 50%        8.955000       3.340000  NaN   NaN
# 75%        9.197500       3.690000  NaN   NaN
# max        9.840000       4.250000  NaN   NaN

# %%
partial_df = df[df['Class'] == 'Partial']
open_df = df[df['Class'] == 'Open']
closed_df = df[df['Class'] == 'Closed']

print("Partial: ", partial_df.shape[0])
print("Open: ", open_df.shape[0])
print("Closed: ", closed_df.shape[0])
# Out:
# Partial:  62
# Open:  100
# Closed:  16
